# %%
import pandas as pd
data=pd.read_csv('C:\\Users\\naga\\OneDrive\\Documents\\nba_draft_combine.csv')
print(data.head())
# Out:
#    SEASON_1 SEASON_2     TEAM_ID               TEAM_NAME  PLAYER_ID  \
# 0      2004  2003-04  1610612747      Los Angeles Lakers        977
# 1      2004  2003-04  1610612757  Portland Trail Blazers        757
# 2      2004  2003-04  1610612747      Los Angeles Lakers        977
# 3      2004  2003-04  1610612757  Portland Trail Blazers        757
# 4      2004  2003-04  1610612757  Portland Trail Blazers        757
#
#         PLAYER_NAME POSITION_GROUP POSITION   GAME_DATE   GAME_ID  ...  \
# 0       Kobe Bryant              G       SG  04-14-2004  20301187  ...
# 1  Damon Stoudamire              G       PG  04-14-2004  20301187  ...
# 2       Kobe Bryant              G       SG  04-14-2004  20301187  ...
# 3  Damon Stoudamire              G       PG  04-14-2004  20301187  ...
# 4  Damon Stoudamire              G       PG  04-14-2004  20301187  ...
#
#           BASIC_ZONE         ZONE_NAME ZONE_ABB       ZONE_RANGE LOC_X  LOC_Y  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4979 entries, 0 to 4978
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      4979 non-null   object
#  1   From        4979 non-null   int64
#  2   To          4979 non-null   int64
#  3   Pos         4979 non-null   object
#  4   Ht          4979 non-null   object
#  5   Wt          4974 non-null   float64
#  6   Birth Date  4961 non-null   object
#  7   Colleges    4628 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 311.3+ KB

# %%
data.describe()
# Out:
#               From           To           Wt
# count  4979.000000  4979.000000  4974.000000
# mean   1988.461137  1992.666600   209.363088
# std      22.410176    23.114979    26.005700
# min    1947.000000  1947.000000   114.000000
# 25%    1971.000000  1975.000000   190.000000
# 50%    1990.000000  1996.000000   210.000000
# 75%    2008.000000  2014.000000   225.000000
# max    2022.000000  2022.000000   360.000000

# %%
data.isnull()
# Out:
#       Player   From     To    Pos     Ht     Wt  Birth Date  Colleges
# 0      False  False  False  False  False  False       False     False
# 1      False  False  False  False  False  False       False     False
# 2      False  False  False  False  False  False       False     False
# 3      False  False  False  False  False  False       False     False
# 4      False  False  False  False  False  False       False     False
# ...      ...    ...    ...    ...    ...    ...         ...       ...
# 4974   False  False  False  False  False  False       False      True
# 4975   False  False  False  False  False  False       False     False
# 4976   False  False  False  False  False  False       False     False
# 4977   False  False  False  False  False  False       False      True
# 4978   False  False  False  False  False  False       False     False
#
# [4979 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Player          0
# From            0
# To              0
# Pos             0
# Ht              0
# Wt              5
# Birth Date     18
# Colleges      351
# dtype: int64

# %%
data_cleaned=data.dropna()
print(data_cleaned)
# Out:
#                     Player  From    To  Pos    Ht     Wt        Birth Date  \
# 0           Alaa Abdelnaby  1991  1995  F-C  6-10  240.0      June 24 1968
# 1          Zaid Abdul-Aziz  1969  1978  C-F   6-9  235.0      April 7 1946
# 2     Kareem Abdul-Jabbar*  1970  1989    C   7-2  225.0     April 16 1947
# 3       Mahmoud Abdul-Rauf  1991  2001    G   6-1  162.0      March 9 1969
# 4        Tariq Abdul-Wahad  1998  2003    F   6-6  223.0   November 3 1974
# ...                    ...   ...   ...  ...   ...    ...               ...
# 4971     Derrick Zimmerman  2006  2006    G   6-3  195.0   December 2 1981
# 4972     Stephen Zimmerman  2017  2017    C   7-0  240.0  September 9 1996
# 4975              Jim Zoet  1983  1983    C   7-1  240.0  December 20 1953
# 4976             Bill Zopf  1971  1971    G   6-1  170.0       June 7 1948
# 4978            Matt Zunic  1949  1949  G-F   6-3  195.0  December 19 1919
#
#                      Colleges
# 0                        Duke
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of player heights
plt.figure(figsize=(8,6))
sns.histplot(data_cleaned, kde=True)
plt.title('Distribution of Player Heights')
plt.xlabel('Height (inches)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\naga\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Boxplot to detect outliers in Wingspan
plt.figure(figsize=(10,12))
sns.boxplot( data=data_cleaned)
plt.title('Boxplot for Wingspan')
plt.show()

# %%
import pandas as pd
# Load the content of the sheet to examine the data structure
sheet_name = 'Big Game Census data (revised)'
data = pd.read_excel('C:\\Users\\naga\\OneDrive\\Documents\\Big Game Census data.xlsx',sheet_name)

# Display the first few rows of the data
data.head()
# Out:
#         Player Name Player Jersey Number Player Position  Player Age  \
# 0    Devin McCourty                  #32            S/FS        30.0
# 1    Danny Amendola                  #80        PR/WR/KR        32.0
# 2  Johnson Bademosi                  #29     CB/SPTM/RCB        27.0
# 3       Chris Hogan                  #15              WR        29.0
# 4     James Develin                  #46           RB/FB        29.0
#
#    Player Weight (lbs.) Years Played Player Birthplace (city, town, etc.)  \
# 0                 195.0            8                               Nanuet
# 1                 190.0            9                        The Woodlands
# 2                 206.0            6                        Silver Spring
# 3                 210.0            5                              Wyckoff
# 4                 255.0            5                        Gilbertsville
#
#   Player Birth State    Player Birthplace (Combo) Player College  ...  \
# ...
